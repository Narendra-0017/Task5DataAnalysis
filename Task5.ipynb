# %% [markdown]
# <a href="https://colab.research.google.com/github/Narendra-0017/Task5DataAnalysis/blob/main/Task5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Create dummy sales data
data = {
    "Product": ["Laptop", "Laptop", "Mobile", "Mobile", "Tablet", "Tablet", "Headphones", "Headphones"],
    "Region": ["North", "South", "North", "East", "West", "South", "East", "West"],
    "Sales": [1200, 800, 1500, 900, 700, 600, 400, 500]
}

df = pd.DataFrame(data)

# Save as CSV
df.to_csv("sales.csv", index=False)

print("✅ sales.csv file created!")
df
# Out:
# ✅ sales.csv file created!
#       Product Region  Sales
# 0      Laptop  North   1200
# 1      Laptop  South    800
# 2      Mobile  North   1500
# 3      Mobile   East    900
# 4      Tablet   West    700
# 5      Tablet  South    600
# 6  Headphones   East    400
# 7  Headphones   West    500

# %%
import matplotlib.pyplot as plt

# Load CSV
df = pd.read_csv("sales.csv")

# Show first rows
print("First 5 rows of dataset:")
print(df.head())

# Group by Product
product_sales = df.groupby("Product")["Sales"].sum()
print("\nTotal sales per product:")
print(product_sales)

# Plot Product Sales
product_sales.plot(kind="bar", title="Total Sales per Product", color="skyblue")
plt.ylabel("Sales")
plt.xlabel("Product")
plt.show()

# Group by Region
region_sales = df.groupby("Region")["Sales"].sum()
print("\nTotal sales per region:")
print(region_sales)

# Plot Region Sales
region_sales.plot(kind="pie", autopct="%1.1f%%", title="Sales Distribution by Region")
plt.ylabel("")
plt.show()
# Out:
# First 5 rows of dataset:
#   Product Region  Sales
# 0  Laptop  North   1200
# 1  Laptop  South    800
# 2  Mobile  North   1500
# 3  Mobile   East    900
# 4  Tablet   West    700
#
# Total sales per product:
# Product
# Headphones     900
# Laptop        2000
# Mobile        2400
# Tablet        1300
# Name: Sales, dtype: int64
# Total sales per region:
# Region
# East     1300
# North    2700
# South    1400
# West     1200
# Name: Sales, dtype: int64
